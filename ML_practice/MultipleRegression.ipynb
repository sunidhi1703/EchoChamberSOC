# %% [markdown]
# <a href="https://colab.research.google.com/github/sunidhi1703/EchoChamberSOC/blob/main/MultipleRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Housing data (INput size in 1000 sq ft, no.of bedrooms and output price in $100k)
X = np.array([
    [1, 1],
    [2, 1],
    [3, 2],
    [4, 3],
    [5, 3]
])
y = np.array([1.5, 2.5, 3.0, 4.5, 5.0])

# Initialize weights and bias
n_samples, n_features = X.shape
w = np.zeros(n_features)
b = 0
alpha = 0.01
iterations = 1000
loss_history = []

# Apply gradient descent
for _ in range(iterations):
    y_pred = X @ w + b
    error = y_pred - y

    # Cost Function
    loss = (1/n_samples) * np.sum(error ** 2)
    loss_history.append(loss)

    # Gradients
    dw = (2/n_samples) * (X.T @ error)
    db = (2/n_samples) * np.sum(error)

    # Update parameters
    w -= alpha * dw
    b -= alpha * db

# Plot cost over iterations
plt.plot(loss_history)
plt.title("Cost Function Over Iterations")
plt.xlabel("Iteration")
plt.ylabel("Mean Squared Error")
plt.grid(True)
plt.show()

#Plot prediction

y_pred = X @ w + b
print("final values of w:",w)
plt.plot(y, label="Actual")
plt.plot(y_pred, label="Predicted", linestyle='--')
plt.legend()
plt.title("Actual vs Predicted Prices")
plt.show()
# Out:
# final values of w: [0.70982543 0.32192154]
